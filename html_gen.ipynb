# %%
import pandas as pd
import os
from bs4 import BeautifulSoup
import csv
import numpy as np

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Meehir\\Documents\\GitHub\\project-2'

# %%
data = open('uefa_club_coefficients/1997_uefa_club_coeff.txt', encoding = 'utf-8')

with open('uefa_club_coefficients/1997_uefa_club_coeff.txt', 'w', encoding = 'utf-8') as f:
    f.write(str(data))
