# %%
import pandas as pd
import json 
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Meehir\\Documents\\GitHub\\project-2'

# %% [markdown]
# seasons = range(1997, 2020)
# lst = []
# df_test = pd.DataFrame
# for year in seasons:
#     file = open('data_files/{}.json'.format(year), encoding='utf-8')
#     lst.append(list(file))

# %% [markdown]
# df = pd.read_json('data_files/2020.json')
# df = pd.read_json('data_files/2020.json')

# %%
seasons = range(1997, 2021)
for i in seasons:
    try:
        file = pd.read_json('data_files/{}.json'.format(i))
        file.to_csv('data_files/{}.csv'.format(i))
        print("{} : worked".format(i))
    except:
        print("{} : FAILED".format(i))
        pass
# Out:
# 1997 : worked
# 1998 : worked
# 1999 : worked
# 2000 : worked
# 2001 : worked
# 2002 : worked
# 2003 : worked
# 2004 : worked
# 2005 : worked
# 2006 : worked
# 2007 : worked
# 2008 : worked
# 2009 : worked
# 2010 : worked
# 2011 : worked
# 2012 : worked
# 2013 : worked
# 2014 : worked
# 2015 : worked
# 2016 : worked
# 2017 : worked
# 2018 : worked
# 2019 : worked
# 2020 : worked

# %%
combined_df = pd.DataFrame

# %%
for i in seasons:
    year = pd.read_csv('data_files/{}.csv'.format(i))
    year.drop(columns=['Unnamed: 0'], inplace=True)
    vars()["df_{}".format(i)] = year

# %% [markdown]
# for i in range(1997, 2021):
#     print("combined_df = combined_df.append(df_{})".format(i))

# %%
combined_df = df_2007.append(df_2008)

combined_df = combined_df.append(df_2009)
combined_df = combined_df.append(df_2010)
combined_df = combined_df.append(df_2011)
combined_df = combined_df.append(df_2012)
combined_df = combined_df.append(df_2013)
combined_df = combined_df.append(df_2014)
combined_df = combined_df.append(df_2015)
combined_df = combined_df.append(df_2016)
combined_df = combined_df.append(df_2017)
combined_df = combined_df.append(df_2018)
combined_df = combined_df.append(df_2019)
combined_df = combined_df.append(df_2020)

# %%
combined_df.to_csv('flatten.csv')
# Out:
#       year         player_name            position age transfermarkt_val  \
# 0     1997             Ronaldo      Centre-Forward  44                 -
# 1     1997             Rivaldo  Attacking Midfield  48                 -
# 2     1997      Sonny Anderson      Centre-Forward  50                 -
# 3     1997     Christian Vieri      Centre-Forward  47                 -
# 4     1997  Christian Karembeu  Defensive Midfield  49                 -
# ...    ...                 ...                 ...  ..               ...
# 4252  2020          Omar Imeri        Right Winger  20           £225Th.
# 4253  2020       Davide Voltan      Second Striker  25           £225Th.
# 4254  2020       Xuesheng Dong      Centre-Forward  31           £225Th.
# 4255  2020    Andrija Majdevac      Centre-Forward  23           £225Th.
# 4256  2020      Tolu Arokodare      Centre-Forward  19           £203Th.
#
#            team_left     league_left      joined_team     joined_league  \
# ...
