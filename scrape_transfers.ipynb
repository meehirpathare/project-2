# %%
from bs4 import BeautifulSoup
import requests

# %%
# https://www.transfermarkt.co.uk/{league_name}/startseite/wettbewerb/{league_id}/plus/?saison_id={season_id}

# %%
url = 'https://www.transfermarkt.co.uk/transfers/saisontransfers/statistik?\land_id=0&ausrichtung=&spielerposition_id=&altersklasse=&leihe=&transferfenster=&saison-id=2020' 

response = requests.get(url, allow_redirects=True)

# %%
response.status_code
# Out:
# 404

# %%
response.text[:1000]
# Out:
# '<html>\r\n<head><title>404 Not Found</title></head>\r\n<body bgcolor="white">\r\n<center><h1>404 Not Found</h1></center>\r\n<hr><center>nginx</center>\r\n</body>\r\n</html>\r\n'

# %%
page = response.text

# %%
soup = BeautifulSoup(page, "lxml")

# %%
print(soup)
